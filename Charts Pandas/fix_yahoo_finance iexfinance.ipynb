# %%
from iexfinance import get_historical_data 
from datetime import datetime

start = datetime(2017, 1, 1) # starting date: year-month-date
end = datetime(2018, 1, 1) # ending date: year-month-date

data = get_historical_data('SPY', start=start, end=end, output_format='pandas') 
data
# Out:
#                 open      high       low     close     volume
# date
# 2017-01-03  218.8967  219.6652  217.7720  219.0913   91366522
# 2017-01-04  219.4609  220.5600  219.4512  220.3947   78744433
# 2017-01-05  220.0931  220.3947  219.3247  220.2196   78379012
# 2017-01-06  220.3460  221.5327  219.7332  221.0075   71559922
# 2017-01-09  220.7157  220.8714  220.2354  220.2780   46939676
# 2017-01-10  220.2974  221.2409  219.8402  220.2780   63771939
# 2017-01-11  220.1807  220.9005  219.4317  220.9005   74650016
# 2017-01-12  220.3169  220.5600  218.8140  220.3460   72113181
# 2017-01-13  220.5406  221.1923  220.5017  220.8518   62717865
# 2017-01-17  220.1320  220.5892  219.6360  220.0737   61240814
# 2017-01-18  220.3509  220.6087  219.7332  220.5600   54793302
# 2017-01-19  220.6476  220.8032  219.2566  219.7430   66608787
# 2017-01-20  220.5114  221.1047  219.8032  220.5503  129168623
# 2017-01-23  220.1710  220.6135  219.1204  219.9764   75061645
# ...

# %%
import fix_yahoo_finance as yf
data = yf.download('SPY', '2018-01-01', '2018-08-22')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  267.839996  268.809998  267.399994  268.769989  266.501160
# 2018-01-03  268.959991  270.640015  268.959991  270.470001  268.186829
# 2018-01-04  271.200012  272.160004  270.540009  271.609985  269.317169
# 2018-01-05  272.510010  273.559998  271.950012  273.420013  271.111938
# 2018-01-08  273.309998  274.100006  272.980011  273.920013  271.607727
# 2018-01-09  274.399994  275.250000  274.079987  274.540009  272.222473
# 2018-01-10  273.679993  274.420013  272.920013  274.119995  271.806000
# 2018-01-11  274.750000  276.119995  274.559998  276.119995  273.789093
# 2018-01-12  276.420013  278.109985  276.079987  277.920013  275.573944
# 2018-01-16  279.350006  280.089996  276.179993  276.970001  274.631958
# 2018-01-17  278.029999  280.049988  276.970001  279.609985  277.249634
# 2018-01-18  279.480011  279.959991  278.579987  279.140015  276.783630
# ...
